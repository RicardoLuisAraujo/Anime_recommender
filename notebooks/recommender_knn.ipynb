# %% [markdown]
# # _Imports and Opening Datasets_

# %%
import pandas as pd
import pickle
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors

# %%
animes_path = "../data/AnimeList.csv"
users_path = "../data/UserList.csv"
reviews_path = "../data/UserAnimeList.parquet"

# %%
reviews_df = pd.read_parquet(reviews_path, columns=["username", "anime_id", "my_score"])
animes_df = pd.read_csv(animes_path)

# %%
reviews_df = reviews_df.merge(
    animes_df[["anime_id", "title", "title_english", "type"]], on="anime_id", how="left"
)

# %%
reviews_df
# Out:
#             username  anime_id  my_score  \
# 0           karthiga        21         9
# 1           karthiga        59         7
# 2           karthiga        74         7
# 3           karthiga       120         7
# 4           karthiga       178         7
# ...              ...       ...       ...
# 80076107  mini_kaila      5940         8
# 80076108  mini_kaila      6030         0
# 80076109  mini_kaila      6500         8
# 80076110  mini_kaila      7058         8
# 80076111  mini_kaila      7088         8
#
#                                           title               title_english  \
# 0                                     One Piece                   One Piece
# 1                                       Chobits                     Chobits
# 2                                  Gakuen Alice                Gakuen Alice
# 3                                 Fruits Basket               Fruits Basket
# 4                                  Ultra Maniac  Ultramaniac - Magical Girl
# ...                                         ...                         ...
# 80076107                   Seiken no Blacksmith       The Sacred Blacksmith
# 80076108                               Needless                    Needless
# 80076109                       Seikon no Qwaser      The Qwaser of Stigmata
# 80076110  Uragiri wa Boku no Namae wo Shitteiru  The Betrayal Knows My Name
# 80076111              Ichiban Ushiro no Daimaou           Demon King Daimao
#
#          type
# 0          TV
# 1          TV
# 2          TV
# 3          TV
# 4          TV
# ...       ...
# 80076107   TV
# 80076108   TV
# 80076109   TV
# 80076110   TV
# 80076111   TV
#
# [80076112 rows x 6 columns]

# %% [markdown]
# # Animes_df Data Exploration and Preparation

# %%
# create user_id
reviews_df["user_id"] = reviews_df.groupby("username").ngroup()

# %%
reviews_df.head()
# Out:
#    username  anime_id  my_score          title               title_english  \
# 0  karthiga        21         9      One Piece                   One Piece
# 1  karthiga        59         7        Chobits                     Chobits
# 2  karthiga        74         7   Gakuen Alice                Gakuen Alice
# 3  karthiga       120         7  Fruits Basket               Fruits Basket
# 4  karthiga       178         7   Ultra Maniac  Ultramaniac - Magical Girl
#
#   type  user_id
# 0   TV   222757
# 1   TV   222757
# 2   TV   222757
# 3   TV   222757
# 4   TV   222757

# %% [markdown]
# ## Analyze the data

# %%
reviews_df = reviews_df[reviews_df.type == "TV"]

# %%
print("Number of Unique Animes:", reviews_df["title"].nunique())
reviews_df["title"].value_counts(ascending=False)
# Out:
# Number of Unique Animes: 4271
# Death Note                             197400
# Code Geass: Hangyaku no Lelouch        165235
# Shingeki no Kyojin                     157033
# Sword Art Online                       156430
# Toradora!                              156059
#                                         ...
# Xiao Hua Xian                               8
# Chara to Otamajakushi Shima                 7
# Xiao Li Yu Li Xian Ji                       4
# Oshi ga Budoukan Ittekuretara Shinu         4
# Xiongmao He Xiao Yan Shu                    3
# Name: title, Length: 4271, dtype: int64

# %%
display(
    reviews_df["title"]
    .value_counts(ascending=False)
    .quantile([0.25, 0.4, 0.5, 0.6, 0.75])
)


third_quantile = (
    reviews_df["title"]
    .value_counts(ascending=False)
    .quantile([0.25, 0.4, 0.5, 0.6, 0.75])
    .values[3]
)
title_counts = reviews_df["title"].value_counts()
reviews_df = reviews_df[
    reviews_df["title"].isin(title_counts.index[title_counts.gt(third_quantile)])
]
# Out:
# 0.25      243.0
# 0.40     1092.0
# 0.50     2828.0
# 0.60     6056.0
# 0.75    15875.5
# Name: title, dtype: float64

# %%
print("Number of Unique Animes:", reviews_df["title"].nunique())
reviews_df["title"].value_counts()
# Out:
# Number of Unique Animes: 1708
# Death Note                                197400
# Code Geass: Hangyaku no Lelouch           165235
# Shingeki no Kyojin                        157033
# Sword Art Online                          156430
# Toradora!                                 156059
#                                            ...
# Di Gi Charat                                6100
# Maria-sama ga Miteru 4th                    6081
# Mushi-Uta                                   6079
# Mutsu Enmei Ryuu Gaiden: Shura no Toki      6072
# Street Fighter II V                         6061
# Name: title, Length: 1708, dtype: int64

# %%
reviews_df[reviews_df["title"] == "Code Geass: Hangyaku no Lelouch"]
# Out:
#                   username  anime_id  my_score  \
# 215       RedvelvetDaisuki      1575        10
# 920              Damonashu      1575         5
# 1364                 bskai      1575        10
# 1750                 Bas_G      1575         9
# 2801            sprite1989      1575         0
# ...                    ...       ...       ...
# 80073458         Scarlet95      1575         0
# 80074096   TheClockworkGuy      1575         8
# 80074252         skillshot      1575        10
# 80074414          Qimosabe      1575        10
# 80074986             Doqac      1575         9
#
#                                     title  \
# 215       Code Geass: Hangyaku no Lelouch
# 920       Code Geass: Hangyaku no Lelouch
# 1364      Code Geass: Hangyaku no Lelouch
# 1750      Code Geass: Hangyaku no Lelouch
# 2801      Code Geass: Hangyaku no Lelouch
# ...                                   ...
# 80073458  Code Geass: Hangyaku no Lelouch
# 80074096  Code Geass: Hangyaku no Lelouch
# 80074252  Code Geass: Hangyaku no Lelouch
# 80074414  Code Geass: Hangyaku no Lelouch
# 80074986  Code Geass: Hangyaku no Lelouch
#
#                                  title_english type  user_id
# 215       Code Geass: Lelouch of the Rebellion   TV   127798
# 920       Code Geass: Lelouch of the Rebellion   TV    35503
# 1364      Code Geass: Lelouch of the Rebellion   TV   190000
# 1750      Code Geass: Lelouch of the Rebellion   TV    19924
# 2801      Code Geass: Lelouch of the Rebellion   TV   264490
# ...                                        ...  ...      ...
# 80073458  Code Geass: Lelouch of the Rebellion   TV   137029
# 80074096  Code Geass: Lelouch of the Rebellion   TV   154990
# 80074252  Code Geass: Lelouch of the Rebellion   TV   262202
# 80074414  Code Geass: Lelouch of the Rebellion   TV   124127
# 80074986  Code Geass: Lelouch of the Rebellion   TV    41916
#
# [165235 rows x 7 columns]

# %%
# Data Curation on username
reviews_df[reviews_df["user_id"] != 0]
# Out:
#             username  anime_id  my_score  \
# 0           karthiga        21         9
# 1           karthiga        59         7
# 2           karthiga        74         7
# 3           karthiga       120         7
# 4           karthiga       178         7
# ...              ...       ...       ...
# 80076107  mini_kaila      5940         8
# 80076108  mini_kaila      6030         0
# 80076109  mini_kaila      6500         8
# 80076110  mini_kaila      7058         8
# 80076111  mini_kaila      7088         8
#
#                                           title               title_english  \
# 0                                     One Piece                   One Piece
# 1                                       Chobits                     Chobits
# 2                                  Gakuen Alice                Gakuen Alice
# 3                                 Fruits Basket               Fruits Basket
# 4                                  Ultra Maniac  Ultramaniac - Magical Girl
# ...                                         ...                         ...
# 80076107                   Seiken no Blacksmith       The Sacred Blacksmith
# 80076108                               Needless                    Needless
# 80076109                       Seikon no Qwaser      The Qwaser of Stigmata
# 80076110  Uragiri wa Boku no Namae wo Shitteiru  The Betrayal Knows My Name
# 80076111              Ichiban Ushiro no Daimaou           Demon King Daimao
#
#          type  user_id
# 0          TV   222757
# 1          TV   222757
# 2          TV   222757
# 3          TV   222757
# 4          TV   222757
# ...       ...      ...
# 80076107   TV   238238
# 80076108   TV   238238
# 80076109   TV   238238
# 80076110   TV   238238
# 80076111   TV   238238
#
# [51049439 rows x 7 columns]

# %%
# reviews_df = reviews_df.sample(frac=1).head(5000000)

# %%
final_dataset = reviews_df.pivot(index="title", columns="user_id", values="my_score")
final_dataset.head()
# Out:
# user_id                            -1        0        1        2       \
# title
# .hack//Roots                           NaN      NaN      NaN      NaN
# .hack//Sign                            4.0      NaN      NaN      NaN
# .hack//Tasogare no Udewa Densetsu      NaN      NaN      NaN      NaN
# 07-Ghost                               NaN      6.0      NaN      NaN
# 11eyes                                 NaN      0.0      NaN      NaN
#
# user_id                             3        4        5        6       \
# title
# .hack//Roots                           NaN      NaN      NaN      NaN
# .hack//Sign                            NaN      NaN      NaN      NaN
# .hack//Tasogare no Udewa Densetsu      NaN      NaN      NaN      NaN
# 07-Ghost                               NaN      NaN      NaN      NaN
# 11eyes                                 NaN      NaN      NaN      NaN
#
# user_id                             7        8       ...   283034   283035  \
# title                                                ...
# .hack//Roots                           NaN      NaN  ...      NaN      NaN
# .hack//Sign                            NaN      NaN  ...      4.0      NaN
# .hack//Tasogare no Udewa Densetsu      NaN      NaN  ...      NaN      NaN
# 07-Ghost                               7.0      NaN  ...      NaN      NaN
# 11eyes                                 5.0      NaN  ...      NaN      NaN
#
# user_id                             283036   283037   283038   283039  \
# title
# .hack//Roots                           NaN      NaN      NaN      NaN
# .hack//Sign                            NaN      NaN      4.0      NaN
# .hack//Tasogare no Udewa Densetsu      NaN      NaN      NaN      NaN
# 07-Ghost                               NaN      NaN      NaN      7.0
# 11eyes                                 NaN      NaN      NaN      NaN
#
# user_id                             283040   283041   283042   283043
# title
# .hack//Roots                           NaN      NaN      NaN      0.0
# .hack//Sign                            NaN      NaN      NaN      NaN
# .hack//Tasogare no Udewa Densetsu      NaN      NaN      NaN      NaN
# 07-Ghost                               8.0      NaN      NaN      NaN
# 11eyes                                 NaN      NaN      NaN      NaN
#
# [5 rows x 281146 columns]

# %%
# final_dataset.fillna(0,inplace=True)
final_dataset.values[final_dataset.isna()] = 0
final_dataset.head()
# Out:
# user_id                            -1        0        1        2       \
# title
# .hack//Roots                           0.0      0.0      0.0      0.0
# .hack//Sign                            4.0      0.0      0.0      0.0
# .hack//Tasogare no Udewa Densetsu      0.0      0.0      0.0      0.0
# 07-Ghost                               0.0      6.0      0.0      0.0
# 11eyes                                 0.0      0.0      0.0      0.0
#
# user_id                             3        4        5        6       \
# title
# .hack//Roots                           0.0      0.0      0.0      0.0
# .hack//Sign                            0.0      0.0      0.0      0.0
# .hack//Tasogare no Udewa Densetsu      0.0      0.0      0.0      0.0
# 07-Ghost                               0.0      0.0      0.0      0.0
# 11eyes                                 0.0      0.0      0.0      0.0
#
# user_id                             7        8       ...   283034   283035  \
# title                                                ...
# .hack//Roots                           0.0      0.0  ...      0.0      0.0
# .hack//Sign                            0.0      0.0  ...      4.0      0.0
# .hack//Tasogare no Udewa Densetsu      0.0      0.0  ...      0.0      0.0
# 07-Ghost                               7.0      0.0  ...      0.0      0.0
# 11eyes                                 5.0      0.0  ...      0.0      0.0
#
# user_id                             283036   283037   283038   283039  \
# title
# .hack//Roots                           0.0      0.0      0.0      0.0
# .hack//Sign                            0.0      0.0      4.0      0.0
# .hack//Tasogare no Udewa Densetsu      0.0      0.0      0.0      0.0
# 07-Ghost                               0.0      0.0      0.0      7.0
# 11eyes                                 0.0      0.0      0.0      0.0
#
# user_id                             283040   283041   283042   283043
# title
# .hack//Roots                           0.0      0.0      0.0      0.0
# .hack//Sign                            0.0      0.0      0.0      0.0
# .hack//Tasogare no Udewa Densetsu      0.0      0.0      0.0      0.0
# 07-Ghost                               8.0      0.0      0.0      0.0
# 11eyes                                 0.0      0.0      0.0      0.0
#
# [5 rows x 281146 columns]

# %%
final_dataset[final_dataset.index == "Dragon Ball"].values
# Out:
# array([[0., 8., 0., ..., 7., 0., 0.]])

# %%
final_dataset[final_dataset.index == "Naruto"].values
# Out:
# array([[6., 7., 0., ..., 5., 0., 0.]])

# %%
# A CSR is a compressed sparse row or compressed row storage matrix.
# It’s just a fancy way of storing only the non-zero entries in a matrix.
csr_data = csr_matrix(final_dataset.values)

# left -> user_id
# right -> anime_id
# float -> rating
print(csr_data[:, 3])
# Out:
#   (15, 0)	9.0
#   (232, 0)	7.0
#   (237, 0)	5.0
#   (247, 0)	8.0
#   (290, 0)	8.0
#   (324, 0)	7.0
#   (328, 0)	7.0
#   (392, 0)	7.0
#   (419, 0)	8.0
#   (431, 0)	7.0
#   (432, 0)	7.0
#   (855, 0)	6.0
#   (970, 0)	7.0
#   (997, 0)	9.0
#   (1019, 0)	5.0
#   (1102, 0)	7.0
#   (1237, 0)	7.0
#   (1271, 0)	7.0
#   (1280, 0)	7.0
#   (1286, 0)	8.0
#   (1500, 0)	6.0
#   (1515, 0)	5.0

# %%
knn = NearestNeighbors(metric="cosine", algorithm="brute", n_neighbors=20, n_jobs=-1)
knn.fit(csr_data)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=20)

# %%
def anime_recommender(anime):

    # get the distance and anime_names of the Animes recommended to the user
    distances, indices = knn.kneighbors(
        final_dataset.loc[anime, :].values.reshape(1, -1), n_neighbors=11
    )
    anime_names = []

    for indice in indices.flatten():
        anime_names.append(final_dataset.index[indice])

    anime_recs = pd.DataFrame({"Distances": distances.flatten()}, index=anime_names)
    anime_recs.index.name = "title"

    return anime_recs

# %%
anime_recommender("Dragon Ball")
# Out:
#                                   Distances
# title
# Dragon Ball                        0.000000
# Dragon Ball Z                      0.223310
# Dragon Ball GT                     0.282797
# Naruto                             0.508912
# Death Note                         0.531604
# Bleach                             0.550518
# Fullmetal Alchemist                0.555498
# Dragon Ball Kai                    0.562159
# Pokemon                            0.562935
# One Piece                          0.566727
# Fullmetal Alchemist: Brotherhood   0.568937

# %%
anime_recommender("Bleach")
# Out:
#                                        Distances
# title
# Bleach                              8.790746e-13
# Naruto                              3.366178e-01
# Naruto: Shippuuden                  3.712829e-01
# Death Note                          3.900309e-01
# Fullmetal Alchemist                 4.248502e-01
# Code Geass: Hangyaku no Lelouch     4.377455e-01
# One Piece                           4.519826e-01
# Fairy Tail                          4.590226e-01
# Fullmetal Alchemist: Brotherhood    4.636950e-01
# Soul Eater                          4.643126e-01
# Code Geass: Hangyaku no Lelouch R2  4.718131e-01

# %%
anime_recommender("One Outs")
# Out:
#                                                    Distances
# title
# One Outs                                        1.119105e-13
# Gyakkyou Burai Kaiji: Ultimate Survivor         5.776778e-01
# Touhai Densetsu Akagi: Yami ni Maiorita Tensai  6.056053e-01
# Major S1                                        6.090202e-01
# Hajime no Ippo                                  6.094884e-01
# Major S2                                        6.148369e-01
# Major S3                                        6.198591e-01
# Hajime no Ippo: New Challenger                  6.202515e-01
# Major S4                                        6.232441e-01
# Major S5                                        6.255552e-01
# Gyakkyou Burai Kaiji: Hakairoku-hen             6.273657e-01

# %%
anime_list = final_dataset.index.tolist()
len(anime_list)
# Out:
# 1708

# %%
anime_list = final_dataset.index.unique().tolist()
predictions_dict = {}

for anime in anime_list:

    predictions_list = []
    distances, indices = knn.kneighbors(
        final_dataset.loc[anime, :].values.reshape(1, -1), n_neighbors=11
    )

    for i in range(1, len(distances.flatten())):

        predictions_list.append(final_dataset.index[indices.flatten()[i]])

    predictions_dict[anime] = predictions_list

# %% [markdown]
# ## Turning the data into a Pickle to use it in Streamlit

# %%
predictions_dict["Naruto"]
# Out:
# ['Naruto: Shippuuden',
#  'Bleach',
#  'Death Note',
#  'Fullmetal Alchemist',
#  'Code Geass: Hangyaku no Lelouch',
#  'Fullmetal Alchemist: Brotherhood',
#  'Shingeki no Kyojin',
#  'One Piece',
#  'Fairy Tail',
#  'Sword Art Online']

# %%
predictions_file_path = "../anime_predictions_list_knn.pkl"

# anime_predictions_json = json.dump(anime_predictions_list)
predictions_file = open(predictions_file_path, "wb")
pickle.dump(predictions_dict, predictions_file)

# %%
predictions_file = open(predictions_file_path, "rb")
output = pickle.load(predictions_file)

# %%
output["Naruto"]
# Out:
# ['Naruto: Shippuuden',
#  'Bleach',
#  'Death Note',
#  'Fullmetal Alchemist',
#  'Code Geass: Hangyaku no Lelouch',
#  'Fullmetal Alchemist: Brotherhood',
#  'Shingeki no Kyojin',
#  'One Piece',
#  'Fairy Tail',
#  'Sword Art Online']

# %% [markdown]
# ## Saving and Storing the Model

# %%
# Its important to use binary mode
filename = "../anime_recommender_knn.pkl"
pickle.dump(knn, open(filename, "wb"))

# %%
# load the model from disk
loaded_model = pickle.load(open(filename, "rb"))
